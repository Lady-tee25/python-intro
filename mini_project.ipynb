# %%
print("=" *40)
print("     PYTHON LEARNER IDENTITY CARD")
print("=" *40)

full_name = input("Enter your full_name:" )
age = input("Enter your age:" )
country = input("Enter your country:" )
focus = input("Enter your focus:" )
course = input("Enter your course:" )

print("Name:", full_name)
print("Age:", age)
print("Country:", country)
print("Focus:", focus)
print("Course:", course)

print("-" *40)
print("Small daily improvements lead to stunning results.")
# Out:
# ========================================
#      PYTHON LEARNER IDENTITY CARD
# ========================================
# Name: Olapade Taiwo
# Age: 20
# Country: Ivory Coast
# Focus: Build A Data Dashboard
# Course: Data Science
# ----------------------------------------
# Small daily improvements lead to stunning results.
